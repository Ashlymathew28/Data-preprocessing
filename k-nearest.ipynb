# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv('C:/Users/ashly/Downloads/archive (2)/conversion_predictors_of_clinically_isolated_syndrome_to_multiple_sclerosis.csv',index_col=0)
df
# Out:
#      Gender  Age  Schooling  Breastfeeding  Varicella  Initial_Symptom  \
# 0         1   34       20.0              1          1              2.0
# 1         1   61       25.0              3          2             10.0
# 2         1   22       20.0              3          1              3.0
# 3         2   41       15.0              1          1              7.0
# 4         2   34       20.0              2          1              6.0
# ..      ...  ...        ...            ...        ...              ...
# 268       2   31        8.0              3          1              9.0
# 269       1   21       15.0              3          3              5.0
# 270       2   19       12.0              3          3             13.0
# 271       2   32       15.0              3          3             15.0
# 272       2   77        6.0              3          3              2.0
#
#      Mono_or_Polysymptomatic  Oligoclonal_Bands  LLSSEP  ULSSEP  VEP  BAEP  \
# ...
