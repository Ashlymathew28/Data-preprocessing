# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('C:/Users/ashly/Downloads/archive/student-alcohol-consumption.csv')

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df
# Out:
#      Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP   F   18     GT3       A     4     4           2
# 1             1     GP   F   17     GT3       T     1     1           1
# 2             2     GP   F   15     LE3       T     1     1           1
# 3             3     GP   F   15     GT3       T     4     2           1
# 4             4     GP   F   16     GT3       T     3     3           1
# 5             5     GP   M   16     LE3       T     4     3           1
# 6             6     GP   M   16     LE3       T     2     2           1
# 7             7     GP   F   17     GT3       A     4     4           2
# 8             8     GP   M   15     LE3       A     3     2           1
# 9             9     GP   M   15     GT3       T     3     4           1
# 10           10     GP   F   15     GT3       T     4     4           1
# 11           11     GP   F   15     GT3       T     2     1           3
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0    395
# school          2
# sex             2
# age             8
# famsize         2
# Pstatus         2
# Medu            5
# Fedu            5
# traveltime      4
# failures        4
# schoolsup       2
# famsup          2
# paid            2
# activities      2
# nursery         2
# higher          2
# internet        2
# romantic        2
# famrel          5
# freetime        5
# goout           5
# Dalc            5
# Walc            5
# health          5
# absences       34
# G1             17
# G2             17
# G3             18
# location        2
# study_time      4
# dtype: int64

# %%
df.loc[subset=('health','activities','freetime')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('health', 'activities', 'freetime')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['Medu'].dropna
# Out:
# <bound method Series.dropna of 0      4
# 1      1
# 2      1
# 3      4
# 4      3
# 5      4
# 6      2
# 7      4
# 8      3
# 9      3
# 10     4
# 11     2
# 12     4
# 13     4
# 14     2
# 15     4
# 16     4
# 17     3
# 18     3
# 19     4
# 20     4
# 21     4
# 22     4
# 23     2
# 24     2
# 25     2
# 26     2
# 27     4
# 28     3
# 29     4
# 30     4
# 31     4
# 32     4
# 33     3
# 34     3
# 35     2
# 36     4
# 37     4
# 38     3
# 39     2
# 40     2
# 41     4
# 42     4
# 43     2
# 44     2
# 45     4
# 46     3
# 47     4
# 48     4
# 49     4
# 50     2
# 51     4
# 52     4
# 53     4
# 54     3
# 55     2
# 56     4
# 57     4
# 58     1
# 59     4
# 60     4
# 61     1
# 62     1
# 63     4
# 64     4
# 65     4
# 66     4
# 67     3
# 68     2
# 69     3
# 70     3
# 71     4
# 72     1
# 73     3
# 74     3
# 75     4
# 76     4
# 77     2
# 78     2
# 79     3
# 80     2
# 81     2
# 82     3
# 83     2
# 84     1
# 85     4
# 86     2
# 87     4
# ...

# %%
df['Fedu'].dropna
# Out:
# <bound method Series.dropna of 0      4
# 1      1
# 2      1
# 3      2
# 4      3
# 5      3
# 6      2
# 7      4
# 8      2
# 9      4
# 10     4
# 11     1
# 12     4
# 13     3
# 14     2
# 15     4
# 16     4
# 17     3
# 18     2
# 19     3
# 20     3
# 21     4
# 22     2
# 23     2
# 24     4
# 25     2
# 26     2
# 27     2
# 28     4
# 29     4
# 30     4
# 31     4
# 32     3
# 33     3
# 34     2
# 35     3
# 36     3
# 37     4
# 38     4
# 39     2
# 40     2
# 41     4
# 42     4
# 43     2
# 44     2
# 45     3
# 46     3
# 47     3
# 48     2
# 49     4
# 50     2
# 51     2
# 52     2
# 53     4
# 54     3
# 55     1
# 56     3
# 57     4
# 58     2
# 59     2
# 60     4
# 61     1
# 62     2
# 63     3
# 64     3
# 65     3
# 66     4
# 67     1
# 68     2
# 69     1
# 70     1
# 71     2
# 72     1
# 73     1
# 74     3
# 75     3
# 76     0
# 77     2
# 78     1
# 79     4
# 80     3
# 81     3
# 82     2
# 83     2
# 84     1
# 85     4
# 86     2
# 87     2
# ...

# %%
df
# Out:
#      Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP   F   18     GT3       A     4     4           2
# 1             1     GP   F   17     GT3       T     1     1           1
# 2             2     GP   F   15     LE3       T     1     1           1
# 3             3     GP   F   15     GT3       T     4     2           1
# 4             4     GP   F   16     GT3       T     3     3           1
# 5             5     GP   M   16     LE3       T     4     3           1
# 6             6     GP   M   16     LE3       T     2     2           1
# 7             7     GP   F   17     GT3       A     4     4           2
# 8             8     GP   M   15     LE3       A     3     2           1
# 9             9     GP   M   15     GT3       T     3     4           1
# 10           10     GP   F   15     GT3       T     4     4           1
# 11           11     GP   F   15     GT3       T     2     1           3
# ...

# %%
df.shape
# Out:
# (395, 30)

# %%
df.head()
# Out:
#    Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0           0     GP   F   18     GT3       A     4     4           2
# 1           1     GP   F   17     GT3       T     1     1           1
# 2           2     GP   F   15     LE3       T     1     1           1
# 3           3     GP   F   15     GT3       T     4     2           1
# 4           4     GP   F   16     GT3       T     3     3           1
#
#    failures schoolsup famsup paid activities nursery higher internet romantic  \
# 0         0       yes     no   no         no     yes    yes       no       no
# 1         0        no    yes   no         no      no    yes      yes       no
# 2         3       yes     no  yes         no     yes    yes      yes       no
# 3         0        no    yes  yes        yes     yes    yes      yes      yes
# 4         0        no    yes  yes         no     yes    yes       no       no
#
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 390         390     MS   M   20     LE3       A     2     2           1
# 391         391     MS   M   17     LE3       T     3     1           2
# 392         392     MS   M   21     GT3       T     1     1           1
# 393         393     MS   M   18     LE3       T     3     2           3
# 394         394     MS   M   19     LE3       T     1     1           1
#
#      failures schoolsup famsup paid activities nursery higher internet  \
# 390         2        no    yes  yes         no     yes    yes       no
# 391         0        no     no   no         no      no    yes      yes
# 392         3        no     no   no         no      no    yes       no
# 393         0        no     no   no         no      no    yes      yes
# 394         0        no     no   no         no     yes    yes      yes
#
#     romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  \
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu        Fedu  traveltime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean   197.000000   16.696203    2.749367    2.521519    1.448101    0.334177
# std    114.170924    1.276043    1.094735    1.088201    0.697505    0.743651
# min      0.000000   15.000000    0.000000    0.000000    1.000000    0.000000
# 25%     98.500000   16.000000    2.000000    2.000000    1.000000    0.000000
# 50%    197.000000   17.000000    3.000000    2.000000    1.000000    0.000000
# 75%    295.500000   18.000000    4.000000    3.000000    2.000000    0.000000
# max    394.000000   22.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'location', 'study_time'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# school        object
# sex           object
# age            int64
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# traveltime     int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# location      object
# study_time    object
# dtype: object

# %%
# cleaning data
df[['Medu','Fedu']]
# Out:
#      Medu  Fedu
# 0       4     4
# 1       1     1
# 2       1     1
# 3       4     2
# 4       3     3
# 5       4     3
# 6       2     2
# 7       4     4
# 8       3     2
# 9       3     4
# 10      4     4
# 11      2     1
# 12      4     4
# 13      4     3
# 14      2     2
# 15      4     4
# 16      4     4
# 17      3     3
# 18      3     2
# 19      4     3
# 20      4     3
# 21      4     4
# 22      4     2
# 23      2     2
# 24      2     4
# 25      2     2
# 26      2     2
# 27      4     2
# 28      3     4
# 29      4     4
# 30      4     4
# 31      4     4
# 32      4     3
# 33      3     3
# 34      3     2
# 35      2     3
# 36      4     3
# 37      4     4
# 38      3     4
# 39      2     2
# 40      2     2
# 41      4     4
# 42      4     4
# 43      2     2
# 44      2     2
# 45      4     3
# 46      3     3
# 47      4     3
# 48      4     2
# 49      4     4
# 50      2     2
# 51      4     2
# 52      4     2
# 53      4     4
# ...

# %%
df.drop(['nursery'],axis=1)
# Out:
#      Unnamed: 0 school sex  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP   F   18     GT3       A     4     4           2
# 1             1     GP   F   17     GT3       T     1     1           1
# 2             2     GP   F   15     LE3       T     1     1           1
# 3             3     GP   F   15     GT3       T     4     2           1
# 4             4     GP   F   16     GT3       T     3     3           1
# 5             5     GP   M   16     LE3       T     4     3           1
# 6             6     GP   M   16     LE3       T     2     2           1
# 7             7     GP   F   17     GT3       A     4     4           2
# 8             8     GP   M   15     LE3       A     3     2           1
# 9             9     GP   M   15     GT3       T     3     4           1
# 10           10     GP   F   15     GT3       T     4     4           1
# 11           11     GP   F   15     GT3       T     2     1           3
# ...

# %%
df['health']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['health']
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# school        object
# sex           object
# age            int64
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# traveltime     int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# location      object
# study_time    object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'location', 'study_time'],
#       dtype='object')

# %%
df.shape
# Out:
# (395, 30)

# %%
# df['freetime']=pd.to_datetime(df['freetime'])
df['freetime']=pd.to_datetime(df['freetime'])

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# school                object
# sex                   object
# age                    int64
# famsize               object
# Pstatus               object
# Medu                   int64
# Fedu                   int64
# traveltime             int64
# failures               int64
# schoolsup             object
# famsup                object
# paid                  object
# activities            object
# nursery               object
# higher                object
# internet              object
# romantic              object
# famrel                 int64
# freetime      datetime64[ns]
# goout                  int64
# Dalc                   int64
# Walc                   int64
# health                 int64
# absences               int64
# G1                     int64
# G2                     int64
# G3                     int64
# location              object
# study_time            object
# dtype: object

# %%
df=df.rename(columns={'sex':'gender','school':'School','nursery':'Nursery'})

# %%
df
# Out:
#      Unnamed: 0 School gender  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP      F   18     GT3       A     4     4           2
# 1             1     GP      F   17     GT3       T     1     1           1
# 2             2     GP      F   15     LE3       T     1     1           1
# 3             3     GP      F   15     GT3       T     4     2           1
# 4             4     GP      F   16     GT3       T     3     3           1
# 5             5     GP      M   16     LE3       T     4     3           1
# 6             6     GP      M   16     LE3       T     2     2           1
# 7             7     GP      F   17     GT3       A     4     4           2
# 8             8     GP      M   15     LE3       A     3     2           1
# 9             9     GP      M   15     GT3       T     3     4           1
# 10           10     GP      F   15     GT3       T     4     4           1
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# School        0
# gender        0
# age           0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# traveltime    0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# Nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# location      0
# study_time    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, School, gender, age, famsize, Pstatus, Medu, Fedu, traveltime, failures, schoolsup, famsup, paid, activities, Nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3, location, study_time]
# Index: []

# %%
df.loc[df.duplicated(subset=['School','famsize','freetime'])].head()
# Out:
#     Unnamed: 0 School gender  age famsize Pstatus  Medu  Fedu  traveltime  \
# 1            1     GP      F   17     GT3       T     1     1           1
# 4            4     GP      F   16     GT3       T     3     3           1
# 6            6     GP      M   16     LE3       T     2     2           1
# 10          10     GP      F   15     GT3       T     4     4           1
# 11          11     GP      F   15     GT3       T     2     1           3
#
#     failures schoolsup famsup paid activities Nursery higher internet  \
# 1          0        no    yes   no         no      no    yes      yes
# 4          0        no    yes  yes         no     yes    yes       no
# 6          0        no     no   no         no     yes    yes      yes
# 10         0        no    yes  yes         no     yes    yes      yes
# 11         0        no    yes   no        yes     yes    yes      yes
#
#    romantic  famrel                      freetime  goout  Dalc  Walc  health  \
# ...

# %%
df.query('study_time=="2 to 5 hours"')
# Out:
#      Unnamed: 0 School gender  age famsize Pstatus  Medu  Fedu  traveltime  \
# 0             0     GP      F   18     GT3       A     4     4           2
# 1             1     GP      F   17     GT3       T     1     1           1
# 2             2     GP      F   15     LE3       T     1     1           1
# 4             4     GP      F   16     GT3       T     3     3           1
# 5             5     GP      M   16     LE3       T     4     3           1
# 6             6     GP      M   16     LE3       T     2     2           1
# 7             7     GP      F   17     GT3       A     4     4           2
# 8             8     GP      M   15     LE3       A     3     2           1
# 9             9     GP      M   15     GT3       T     3     4           1
# 10           10     GP      F   15     GT3       T     4     4           1
# 13           13     GP      M   15     GT3       T     4     3           2
# ...

# %%
graph=df['age'].value_counts().plot(kind='bar',title='Age Grouping')
graph.set_xlabel('age')
graph.set_ylabel('Count')
graph
# Out:
# <Axes: title={'center': 'Age Grouping'}, xlabel='age', ylabel='Count'>

# %%
graph=df['age'].value_counts().plot(kind='bar',title="ages")
graph.set_xlabel('age')
graph.set_ylabel('count')
graph
# Out:
# <Axes: title={'center': 'ages'}, xlabel='age', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'location', 'study_time'],
#       dtype='object')

# %%
gp2=df['absences'].plot(kind='hist',bins=20,title='Absence Count')
gp2
# Out:
# <Axes: title={'center': 'Absence Count'}, ylabel='Frequency'>

# %%
gp2=df['absences'].plot(kind='kde',title='Absence Count')
gp2
# Out:
# <Axes: title={'center': 'Absence Count'}, ylabel='Density'>

# %%
# feature r/n
df.plot(kind='scatter',x='absences',y='sex',title="relation b/n gender and abesence")
# Out:
# <Axes: title={'center': 'relation b/n gender and abesence'}, xlabel='absences', ylabel='sex'>

# %%
df.plot(kind='scatter',x='age',y='absences',title='r/n b/n age and absence')
# Out:
# <Axes: title={'center': 'r/n b/n age and absence'}, xlabel='age', ylabel='absences'>

# %%
sns.scatterplot(x='absences',y='sex',hue='sex',data=df)
# Out:
# <Axes: xlabel='absences', ylabel='sex'>

# %%
sns.scatterplot(x='age',y='absences',hue='age',data=df)
# Out:
# <Axes: xlabel='age', ylabel='absences'>

# %%
sns.pairplot(df,vars=['sex','traveltime','absences'])

# %%
dfcorr=df[['sex','traveltime','absences']].dropna().corr()
# Out:
# C:\Users\ashly\AppData\Local\Temp\ipykernel_22448\835050275.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfcorr=df[['sex','traveltime','absences']].dropna().corr()

# %%
sns.heatmap(dfcorr,annot=True)
# Out:
# <Axes: >
